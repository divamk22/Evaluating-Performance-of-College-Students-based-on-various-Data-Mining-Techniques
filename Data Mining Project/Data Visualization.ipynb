# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
# %matplotlib inline

# %%
ds = pd.read_csv("imbalanced_edm_vit_data.csv")
ds.head()
# Out:
#                 Email Address Gender Nationality  \
# 0  kumarkaushik1580@gmail.com   Male      Indian
# 1  divam.kesharwani@gmail.com   Male      Indian
# 2     vbhandari2999@gmail.com   Male      Indian
# 3         unnatbasa@gmail.com   Male      Indian
# 4    devamsheth0806@gmail.com   Male      Indian
#
#                        Mother Tongue/ First Language  \
# 0                                              Hindi
# 1                                              Hindi
# 2                                            English
# 3  Others(Tamil/Telugu/Kannada/Malayalam/Marathi/...
# 4  Others(Tamil/Telugu/Kannada/Malayalam/Marathi/...
#
#   Teaching Language in University High School Percentage  \
# 0                         English    Excellent (90-100%)
# 1                         English    Excellent (90-100%)
# 2                         English    Excellent (90-100%)
# 3                         English    Excellent (90-100%)
# ...

# %%
ds.shape
# Out:
# (321, 25)

# %%
ds['Result'].value_counts()
# Out:
# Pass    311
# Fail     10
# Name: Result, dtype: int64

# %%
sns.countplot(x = "Result", hue = "Result", data = ds)

# %%
plt.figure(figsize=(15,15))
plt.subplot(421)
sns.countplot(x = "Gender", hue = "Result", data = ds)
plt.subplot(422)
sns.countplot(x = "Nationality", hue = "Result", data = ds)
plt.subplot(423)
sns.countplot(x = "Mother Tongue/ First Language", hue = "Result", data = ds)
plt.subplot(424)
sns.countplot(x = "High School Percentage", hue = "Result", data = ds)
plt.subplot(425)
sns.countplot(x = "Present Year of Study (Status)", hue = "Result", data = ds)
plt.subplot(426)
sns.countplot(x = "Living Location", hue = "Result", data = ds)
plt.subplot(427)
sns.countplot(x = "Does Student has scholarship?", hue = "Result", data = ds)
plt.subplot(428)
sns.countplot(x = "How the student comes to University?", hue = "Result", data = ds)

# %%
plt.figure(figsize=(15,15))
plt.subplot(421)
sns.countplot(x = "Family Size", hue = "Result", data = ds)
plt.subplot(422)
sns.countplot(x = "Total family income", hue = "Result", data = ds)
plt.subplot(423)
sns.countplot(x = "Parents Marital Status", hue = "Result", data = ds)
plt.subplot(424)
sns.countplot(x = "High School Percentage", hue = "Result", data = ds)
plt.subplot(425)
sns.countplot(x = "Father's Qualification", hue = "Result", data = ds)
plt.subplot(426)
sns.countplot(x = "Mother's Qualification", hue = "Result", data = ds)
plt.subplot(427)
sns.countplot(x = "Father's Occupation Status", hue = "Result", data = ds)
plt.subplot(428)
sns.countplot(x = "Mother's Occupation Status", hue = "Result", data = ds)

# %%
plt.figure(figsize=(15,15))
plt.subplot(321)
sns.countplot(x = "No. of Friends", hue = "Result", data = ds)
plt.subplot(322)
sns.countplot(x = "Average number of hours you spend with your friends in one week", hue = "Result", data = ds)
plt.subplot(323)
sns.countplot(x = "CGPA", hue = "Result", data = ds)
plt.subplot(324)
sns.countplot(x = "Does the student have any outside sponsorship for study?", hue = "Result", data = ds)
plt.subplot(325)
sns.countplot(x = "Religion", hue = "Result", data = ds)
